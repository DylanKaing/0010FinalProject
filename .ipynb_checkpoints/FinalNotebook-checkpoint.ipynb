# %% [markdown]
# # Merged Best Neighborhood Final Notebook
#
# ## Setting Up The Three Metrics
#     Before we are actually able to choose the overral best neighborhood with the three metric we need to import pandas.  This will allow us to read in the three data sets and merge them together to see which neighborhood appears the most often within the data sets.

# %% [markdown]
# ### DATASET 1 = SCHOOL ENROLLMENT NUMBERS

# %% [markdown]
# ## Intro
# To choose the best neighborhood in Pittsburgh, I chose the amount of enrollments in each neighborhood as a metric.  Since the number of students that are enrolled within each neighborhood shows the importance of education within each neighborhood.  But as well the availability of education to the youth of each area.
#
# Before getting into the code and sorting through the data set we first need to import pandas and matplotlib so that we can read in the data set and eventually plot it.  After doing so I can now able to drop all the columns that I do not need to look at and then drop all the rows that have no data for students enrolled.  Then I am able to sort the data and see the first top 20.

# %%
import pandas as pd
import matplotlib.pyplot as plt

#read in the dataset
enrollData = pd.read_csv("enrollments.csv")

#drop columns useless columns that aren't needed
enrollData = enrollData.drop(columns=["african_american","american_indian","asian__not_pacific_islander","hispanic","multiracial"
                                     ,"native_hawaiian_or_other_pacific_islander","white","attending_feeder","attending_nonfeeder","student_count_redactions"
                                     ,"total_with_feeder_status","feeder_count_redactions"])

#drops rows that do not have any data
enrollData=enrollData.dropna()

#prints the first 20 neighborhoods
enrollData.head(20)

#sorts the data with the top being the most students enrolled
enrollData = enrollData.sort_values(by=['total_students_enrolled'], ascending=False)

# %%
enrollData.head(20)
# Out:
#             neighborhood  total_students_enrolled grade_level
# 107              Carrick                    541.0         K-5
# 105            Brookline                    526.0         K-5
# 286              Carrick                    378.0        9-12
# 99             Beechview                    339.0         K-5
# 284            Brookline                    310.0        9-12
# 104     Brighton Heights                    296.0         K-5
# 197              Carrick                    293.0         6-8
# 168  Squirrel Hill South                    286.0         K-5
# 131       Homewood North                    282.0         K-5
# 195            Brookline                    276.0         6-8
# 117           East Hills                    275.0         K-5
# 160             Sheraden                    275.0         K-5
# 134            Knoxville                    257.0         K-5
# 148    Northview Heights                    254.0         K-5
# 346  Squirrel Hill South                    249.0        9-12
# 118         East Liberty                    247.0         K-5
# 112      Crafton Heights                    230.0         K-5
# 129            Hazelwood                    221.0         K-5
# 132       Homewood South                    218.0         K-5
# 140   Marshall-Shadeland                    218.0         K-5

# %% [markdown]
# It can be seen in the table above that there are actually multiple groups of students that are actually being accounted for instead of just the whole total K-12.  Instead they are separted which causes a neighborhood to appear more than once within the top 20.  Which is why I need to group by neighborhoods and add up all the total students within each grade cluster.

# %%
# aggregate function to combine all the neighborhoods and add up all the students
combine = {"total_students_enrolled":"sum"}

# groups by neighborhood and adds up all the students
enrollData = enrollData.groupby(enrollData['neighborhood']).aggregate(combine)

# resorts the data in ascending order with the highest total students first
enrollData = enrollData.sort_values(by=['total_students_enrolled'], ascending=False)

# prints the top 20 out
enrollData.head(20)
# Out:
#                           total_students_enrolled
# neighborhood
# Carrick                                    1276.0
# Brookline                                  1169.0
# Beechview                                   794.0
# Sheraden                                    694.0
# Squirrel Hill South                         679.0
# Knoxville                                   616.0
# Brighton Heights                            598.0
# Homewood North                              589.0
# East Hills                                  569.0
# Hazelwood                                   567.0
# Crafton Heights                             539.0
# Northview Heights                           527.0
# Garfield                                    520.0
# Lincoln-Lemington-Belmar                    508.0
# East Liberty                                496.0
# Greenfield                                  487.0
# Mt. Oliver Borough                          479.0
# Homewood South                              477.0
# Marshall-Shadeland                          467.0
# Perry South                                 443.0

# %% [markdown]
# Now that a neighborhood will only appear once within the dataframe and have the correct total amount of students I am now able to plot the data as a bar graph to show the drastic differences between each neighborhood.

# %%
# Plot the data set as a bar graph
enrollData.plot(kind='bar',figsize=(20,10))

# set plot title and axis lables
plt.title('Total Student Enrollment Per Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Students Enrolled')
# Out:
# Text(0, 0.5, 'Number of Students Enrolled')

# %% [markdown]
# # OUTCOME!!!
# ## Based off of the top 20 and the bar graph with no close contenders solely based on this metric Carrick wins as it has the most enrolled students!!!!!!

# %% [markdown]
# ### DATASET 2 = REPORTED CRIME

# %% [markdown]
# ***Introduction***:
#     In this project, I am looking for the best neighborhood in Pittsburgh. By using data sets, we will analyze different criterias from 3 different datasets to show subjectively which is the "best" neighborhood in Pittsburgh. For me,  using the Police arrest data dataset.
# My metric is based on the number of crimes for each neighborhood. I am using the Police arrest dataset

# %% [markdown]
# First import pandas and import data

# %%
import pandas as pd
import matplotlib.pyplot as plt

#read in the dataset
df = pd.read_csv("crime.csv")
df =df.drop(df.iloc[:,10:],axis = 1)
df
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0      1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1      1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2      1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3      1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4      1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# ...        ...       ...   ...    ...  ...                  ...
# 61289  2056476  23029563  46.0      M    W  2023-02-26T16:44:00
# 61290  2056477  23029599  29.0      M    W  2023-02-26T17:52:00
# 61291  2056478  23029601  26.0      M    W  2023-02-26T18:00:00
# 61292  2056479  23029649  35.0      M    B  2023-02-26T19:47:00
# 61293  2056480  23029721  24.0      M    B  2023-02-27T00:30:00
#
#                                          ARRESTLOCATION  \
# 0             4700 Block Centre AV Pittsburgh, PA 15213
# 1      4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2            900 Block Freeport RD Fox Chapel, PA 15238
# 3           Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4             900 Block Woodlow ST Pittsburgh, PA 15205
# ...                                                 ...
# 61289      1300 Block Goettmann ST Pittsburgh, PA 15212
# 61290       700 Block Brookline BL Pittsburgh, PA 15226
# 61291          Forbes AV & Wood ST Pittsburgh, PA 15222
# 61292        1300 Block Sherman AV Pittsburgh, PA 15212
# 61293         Middle ST & Emlin ST Pittsburgh, PA 15212
#
#                                                 OFFENSES  \
# 0                                     3929 Retail Theft.
# 1           13(a)(16) Possession of Controlled Substance
# 2                                     3929 Retail Theft.
# 3      5503 Disorderly Conduct. / 5505 Public Drunken...
# 4      2702 Aggravated Assault. / 2705 Recklessy Enda...
# ...                                                  ...
# 61289  2701 Simple Assault. / 2706 Terroristic Threat...
# 61290  5101 Obstructing Admin. of Law  / 5104 Resisti...
# 61291                                 9501 Bench Warrant
# 61292  2701 Simple Assault. / 5104 Resisting Arrest o...
# 61293  5104 Resisting Arrest or Other Law Enforcement...
#
#                                        INCIDENTLOCATION  \
# 0             4700 Block Centre AV Pittsburgh, PA 15213
# 1      4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2            900 Block Freeport RD Fox Chapel, PA 15238
# 3           Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4             900 Block Woodlow ST Pittsburgh, PA 15205
# ...                                                 ...
# 61289      1300 Block Goettmann ST Pittsburgh, PA 15212
# 61290       700 Block Brookline BL Pittsburgh, PA 15226
# 61291          Forbes AV & Wood ST Pittsburgh, PA 15222
# 61292        1300 Block Sherman AV Pittsburgh, PA 15212
# 61293       600 Block East Ohio ST Pittsburgh, PA 15212
#
#             INCIDENTNEIGHBORHOOD
# 0                     Bloomfield
# 1                   Outside City
# 2                       Westwood
# 3                 East Allegheny
# 4                Crafton Heights
# ...                          ...
# 61289                  Troy Hill
# 61290                  Brookline
# 61291  Central Business District
# 61292         Central North Side
# 61293             East Allegheny
#
# [61294 rows x 10 columns]

# %% [markdown]
# Make a table view specific to Columns with what is relevant.

# %%
# group by neighborhood and count arrests
arrest_counts = df.groupby("INCIDENTNEIGHBORHOOD")['INCIDENTNEIGHBORHOOD'].count()

#sort by most to least
arrest_counts = arrest_counts.sort_values(ascending = True)

df.groupby('OFFENSES')['OFFENSES'].count().sort_values(ascending = False)
# Out:
# OFFENSES
# 2701 Simple Assault.                                                                                                                                                                                                                                                                                   4141
# 9015 Failure To Appear/Arrest on Attachment Order                                                                                                                                                                                                                                                      3375
# 9501 Bench Warrant                                                                                                                                                                                                                                                                                     3182
# 13(a)(32) Paraphernalia - Use or Possession                                                                                                                                                                                                                                                            1121
# 13(a)(31) Marijuana: Possession Small Amount                                                                                                                                                                                                                                                           1083
#                                                                                                                                                                                                                                                                                                        ...
# 2706 Terroristic Threats. / 1543 Driving While Operating Privilege is Suspended or Revoked. / 3736 Reckless Driving / 3802(a)(1) DUI - General Impairment                                                                                                                                                 1
# 2706 Terroristic Threats. / 1543 Driving While Operating Privilege is Suspended or Revoked. / 3742 Accidents Involving Death or Personal Injury / 3742.1 Accident Involv. Death/Inj. While not Licensed / 3802(a)(1) DUI - General Impairment / 3802(c) DUI - Highest Rate of Alcohol - BAC >= .16%       1
# 2706 Terroristic Threats. / 1543 Driving While Operating Privilege is Suspended or Revoked. / 3745 Accidents Involving Damage to Unattended Veh.or Prop. / 3802(a)(1) DUI - General Impairment                                                                                                            1
# 2706 Terroristic Threats. / 1543 Driving While Operating Privilege is Suspended or Revoked. / 3745 Accidents Involving Damage to Unattended Veh.or Prop. / 3802(a)(1) DUI - General Impairment / 3809(a) Restriction on Alcoholic Beverages in Vehicle                                                    1
# 9999 Miscellaneous Report (No Crime) / 9129 Miscellaneous Investigation                                                                                                                                                                                                                                   1
# Name: OFFENSES, Length: 16563, dtype: int64

# %%
## Plot results in bar graph
arrest_counts.plot(kind='bar',figsize=(20,10))

# set plot title and axis lables
plt.title('Arrests by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Arrests')

#Display plot
plt.show()

df.groupby("INCIDENTNEIGHBORHOOD")['INCIDENTNEIGHBORHOOD'].count().sort_values(ascending = False)
# Out:
# INCIDENTNEIGHBORHOOD
# Central Business District    3785
# South Side Flats             3186
# Carrick                      2199
# East Allegheny               2014
# Homewood South               1941
#                              ...
# Ridgemont                      35
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %% [markdown]
# # OUTCOME!!!
# ## Based off of the top 20 and the bar graph with no close contenders solely based on this metric Central Business District LOSES because it has the most crimes. M

# %% [markdown]
# ### DATASET 3 = PLAYGROUNDS

# %%
#imprt pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the csv, group by neighborhood + get count, sort high to low
df3 = pd.read_csv("playground.csv")
df3 = df3.groupby("neighborhood").size().reset_index(name="count")
df3 = df3.sort_values(by=['count'], ascending=False)
df3
# Out:
#            neighborhood  count
# 56  Squirrel Hill South      8
# 4             Beechview      5
# 52    South Side Slopes      5
# 0      Allegheny Center      4
# 5           Beltzhoover      4
# ..                  ...    ...
# 41        New Homestead      1
# 42              Oakwood      1
# 43          Perry North      1
# 44          Perry South      1
# 67              Windgap      1
#
# [68 rows x 2 columns]

# %%
#plot the data into bar graph
ax = df3.plot.bar(x="neighborhood", y="count", rot=90,figsize=(20,10))
ax.set_xlabel("Neighborhood")
ax.set_ylabel("Playgrounds Count")
ax.set_title("Number of Playgrounds by Neighborhood")
plt.show()

# %% [markdown]
# #MERGING ALL DATASETS

# %%
arrests = pd.read_csv("crime.csv")
arrests = arrests.rename(columns={"INCIDENTNEIGHBORHOOD":"neighborhood"})

# %%
playgrounds = pd.read_csv("playground.csv")

# %%
enrollment = pd.read_csv("enrollments.csv")

# %%
# Group the arrest data by neighborhood and count the number of arrests in each neighborhood
arrest_counts = arrests.groupby("neighborhood").size().reset_index(name="arrest_count")


# Group the playground data by neighborhood and count the number of playgrounds in each neighborhood
playground_counts = playgrounds.groupby("neighborhood").size().reset_index(name="playground_count")

# Group the enrollment data by neighborhood and sum the total enrollment in each neighborhood
enrollment_counts = enrollData.groupby("neighborhood")["total_students_enrolled"].sum().reset_index(name="enrollment_count")

# %%
# Merge the arrest, playground, and enrollment data into one dataframe
merged_data = pd.merge(arrest_counts, playground_counts, on="neighborhood", how="outer")
merged_data = pd.merge(merged_data, enrollment_counts, on="neighborhood", how="outer")

# %%
# Sort the merged dataframe based on the specified criteria
merged_data.sort_values(by=["arrest_count"], ascending=True, inplace=True)
merged_data.sort_values(by=["enrollment_count"], ascending=False, inplace=True)
merged_data.sort_values(by=["playground_count"], ascending=False, inplace=True)
merged_data
# Out:
#                  neighborhood  arrest_count  playground_count  \
# 83        Squirrel Hill South         771.0               8.0
# 79          South Side Slopes         752.0               5.0
# 7                   Beechview        1116.0               5.0
# 41              Highland Park         530.0               4.0
# 75                   Sheraden        1192.0               4.0
# ..                        ...           ...               ...
# 59              North Oakland         409.0               NaN
# 22                    Chateau         415.0               NaN
# 60                North Shore         759.0               NaN
# 18         Central North Side         783.0               NaN
# 16  Central Business District        3785.0               NaN
#
#     enrollment_count
# 83             679.0
# 79             177.0
# 7              794.0
# 41             412.0
# 75             694.0
# ..               ...
# 59               NaN
# 22               NaN
# 60               NaN
# 18               NaN
# 16               NaN
#
# [101 rows x 4 columns]
